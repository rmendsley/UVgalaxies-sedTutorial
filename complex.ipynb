# %%
import numpy as np 
import bagpipes as pipes
import matplotlib.pyplot as plt
from astropy.io import fits

ACS_bands = ['F435W','F606W','F775W','F814W','F850LP']
NIRCam_bands = ['F090W','F115W','F150W','F200W',
                'F277W','F335M','F356W','F410M','F444W']
allBands = ACS_bands + NIRCam_bands

def buildFilterList():
    filtList = ['filters/ACS_'+band for band in ACS_bands] #paths to filter transmission curves
    filtList += ['filters/NIRCam_'+band for band in NIRCam_bands]
    return filtList

def load_photometry(ID):
    #function needed for bagpipes that outputs photometry for a given object ID
    #ID value is assumed to be a string here

    #load in photometry catalog. Here using the JADES deep GOODS-S catalog of HST+NIRCam photometry.
    cat = fits.open('data/hlsp_jades_jwst_nircam_goods-s-deep_photometry_v1.0_catalog.fits')
    IDs = cat['KRON_CONV'].data['ID'].astype(str) #ID array of catalog -- make string type for ease below
    i = list(IDs).index(ID) #index of photometric catalog corresponding to ID of interest

    fluxes = []; flux_errs = []
    for band in allBands:
        fluxes.append(cat['KRON_CONV'].data[band+'_KRON'][i]/1000.) #put in microJy
        flux_errs.append(cat['KRON_CONV'].data[band+'_KRON_e'][i]/1000.)
    
    # Turn these into a 2D array.
    photometry = np.c_[fluxes, flux_errs]
    
    #assign huge errors for bands with missing fluxes
    flagOnes = (photometry[:,1]<=0) | (np.isnan(photometry[:,1])) #catalog errors <=0 or nan
    photometry[flagOnes] = [0.,10**10]

    #Add systematic uncertainties to photometry. 3% for ACS, 5% for NIRCam
    photometry[:len(ACS_bands),1] = np.sqrt(photometry[:len(ACS_bands),1]**2 + (0.03*photometry[:len(ACS_bands),0])**2)
    photometry[len(ACS_bands):,1] = np.sqrt(photometry[len(ACS_bands):,1]**2 + (0.05*photometry[len(ACS_bands):,0])**2)

    return photometry

###################################################################

filtList = buildFilterList()
ID = "114613" #F775W dropout (z~6) in GOODS-S
galaxy = pipes.galaxy(ID, load_photometry, spectrum_exists=False, photometry_exists=True, filt_list=filtList, phot_units='mujy')

#ID, load_data, spec_units='ergscma', phot_units='mujy', spectrum_exists=True, photometry_exists=True, filt_list=None, out_units='ergscma', load_indices=None, index_list=None, index_redshift=None, 
#input_spec_cov_matrix=False

fig = galaxy.plot()

# %%
#https://github.com/ACCarnall/bagpipes/blob/master/examples/Further%20Examples%202%20-%20The%20Leja2019%20non-parametric%20continuity%20SFH%20Model.ipynb
#Following above notebook, fit with the non-parametric continuity model described in Leja+19
#With the current version of bagpipes, have to adopt some fixed redshift. 
#Will be using z=6.0, consistent with photo-z from fairlyBasic.ipynb output.

#Star formation history
continuity = {}                          # continuity SFH 
continuity["massformed"] = (3., 12.)     # vary log_10(M*/M_solar) between 3 and 12
continuity["metallicity"] = (0.01, 2.5)  # vary Z between 0.01 and 2.5 Z_solar
continuity["metallicity_prior"] = "log_10"   

continuity["bin_edges"] = [0., 3., 10., 30., 100., 250., 500.] #in Myr
for i in range(1, len(continuity["bin_edges"])-1):
    continuity["dsfr" + str(i)] = (-10., 10.)
    continuity["dsfr" + str(i) + "_prior"] = "student_t"
    #continuity["dsfr" + str(i) + "_prior_scale"] = 0.3  # Defaults to this value as in Leja19, but can be set
    #continuity["dsfr" + str(i) + "_prior_df"] = 2       # Defaults to this value as in Leja19, but can be set

#Dust attenuation
dust = {}                                 # Dust component
dust["type"] = "Calzetti"                 # Define the shape of the attenuation curve
dust["Av"] = (1e-3, 2.)                     # Vary Av between 0 and 2 magnitudes
dust["Av_prior"] = "log_10"
dust["eta"] = 1.                          # Multiplicative factor on Av for stars in birth clouds
# Dust emission parameters -- only important if rest mid/far-IR data is used
dust["qpah"] = 2.          # PAH mass fraction
dust["umin"] = 1.          # Lower limit of starlight intensity distribution
dust["gamma"] = 0.01       # Fraction of stars at umin

#Nebular emission. logU is the only free parameter for nebular emission in bagpipes
nebular = {}
nebular["logU"] = (-4.0,-2.0)             # Log_10 of the ionization parameter.

fit_instructions = {}                     # The fit instructions dictionary
fit_instructions["redshift"] = 6.0
fit_instructions["continuity"] = continuity
fit_instructions["dust"] = dust
fit_instructions["nebular"] = nebular

fit = pipes.fit(galaxy, fit_instructions, run='complex')

fit.fit(verbose=True)
# Out:
# Bagpipes: fitting object 114613
#
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  400
#  dimensionality =    9
#  resuming from previous job
#  *****************************************************
#  Starting MultiNest
# Acceptance Rate:                        0.415896
# Replacements:                                450
# Total Samples:                              1082
# Nested Sampling ln(Z):                 -2.080607
# Acceptance Rate:                        0.289352
# Replacements:                                500
# Total Samples:                              1728
# Nested Sampling ln(Z):                 -1.397146
# Acceptance Rate:                        0.248644
# Replacements:                                550
# Total Samples:                              2212
# Nested Sampling ln(Z):                 -0.999566
# Acceptance Rate:                        0.215208
# Replacements:                                600
# Total Samples:                              2788
# Nested Sampling ln(Z):                 -0.715601
# Acceptance Rate:                        0.188297
# Replacements:                                650
# Total Samples:                              3452
# Nested Sampling ln(Z):                 -0.494929
# Acceptance Rate:                        0.169287
# Replacements:                                700
# Total Samples:                              4135
# Nested Sampling ln(Z):                 -0.314882
# Acceptance Rate:                        0.152161
# Replacements:                                750
# Total Samples:                              4929
# Nested Sampling ln(Z):                 -0.159539
# Acceptance Rate:                        0.144535
# Replacements:                                800
# Total Samples:                              5535
# Nested Sampling ln(Z):                 -0.022469
# Acceptance Rate:                        0.138122
# Replacements:                                850
# Total Samples:                              6154
# Nested Sampling ln(Z):                 60.041871
# Acceptance Rate:                        0.129646
# Replacements:                                900
# Total Samples:                              6942
# Nested Sampling ln(Z):                107.749793
# Acceptance Rate:                        0.121842
# Replacements:                                950
# Total Samples:                              7797
# Nested Sampling ln(Z):                158.647674
# Acceptance Rate:                        0.123503
# Replacements:                               1000
# Total Samples:                              8097
# Nested Sampling ln(Z):                217.572645
# Acceptance Rate:                        0.126156
# Replacements:                               1050
# Total Samples:                              8323
# Nested Sampling ln(Z):                272.670283
# Acceptance Rate:                        0.128205
# Replacements:                               1100
# Total Samples:                              8580
# Nested Sampling ln(Z):                315.679752
# Acceptance Rate:                        0.130682
# Replacements:                               1150
# Total Samples:                              8800
# Nested Sampling ln(Z):                350.968560
# Acceptance Rate:                        0.132057
# Replacements:                               1200
# Total Samples:                              9087
# Nested Sampling ln(Z):                389.939662
# Acceptance Rate:                        0.132753
# Replacements:                               1250
# Total Samples:                              9416
# Nested Sampling ln(Z):                420.279175
# Acceptance Rate:                        0.133361
# Replacements:                               1300
# Total Samples:                              9748
# Nested Sampling ln(Z):                443.930735
# Acceptance Rate:                        0.134382
# Replacements:                               1350
# Total Samples:                             10046
# Nested Sampling ln(Z):                462.360619
# Acceptance Rate:                        0.135161
# Replacements:                               1400
# Total Samples:                             10358
# Nested Sampling ln(Z):                481.266145
# Acceptance Rate:                        0.136638
# Replacements:                               1450
# Total Samples:                             10612
# Nested Sampling ln(Z):                496.398366
# Acceptance Rate:                        0.137539
# Replacements:                               1500
# Total Samples:                             10906
# Nested Sampling ln(Z):                508.887285
# Acceptance Rate:                        0.138678
# Replacements:                               1550
# Total Samples:                             11177
# Nested Sampling ln(Z):                521.080923
# Acceptance Rate:                        0.138829
# Replacements:                               1600
# Total Samples:                             11525
# Nested Sampling ln(Z):                531.224056
# Acceptance Rate:                        0.138574
# Replacements:                               1650
# Total Samples:                             11907
# Nested Sampling ln(Z):                538.303613
# Acceptance Rate:                        0.138527
# Replacements:                               1700
# Total Samples:                             12272
# Nested Sampling ln(Z):                544.802555
# Acceptance Rate:                        0.138209
# Replacements:                               1750
# Total Samples:                             12662
# Nested Sampling ln(Z):                551.518493
# Acceptance Rate:                        0.138323
# Replacements:                               1800
# Total Samples:                             13013
# Nested Sampling ln(Z):                557.780880
# Acceptance Rate:                        0.137926
# Replacements:                               1850
# Total Samples:                             13413
# Nested Sampling ln(Z):                561.752064
# Acceptance Rate:                        0.136328
# Replacements:                               1900
# Total Samples:                             13937
# Nested Sampling ln(Z):                566.028598
# Acceptance Rate:                        0.136430
# Replacements:                               1950
# Total Samples:                             14293
# Nested Sampling ln(Z):                569.649333
# Acceptance Rate:                        0.135199
# Replacements:                               2000
# Total Samples:                             14793
# Nested Sampling ln(Z):                573.050891
# Acceptance Rate:                        0.132953
# Replacements:                               2050
# Total Samples:                             15419
# Nested Sampling ln(Z):                576.713931
# Acceptance Rate:                        0.131201
# Replacements:                               2100
# Total Samples:                             16006
# Nested Sampling ln(Z):                580.171788
# Acceptance Rate:                        0.130051
# Replacements:                               2150
# Total Samples:                             16532
# Nested Sampling ln(Z):                582.668481
# Acceptance Rate:                        0.128874
# Replacements:                               2200
# Total Samples:                             17071
# Nested Sampling ln(Z):                585.174942
# Acceptance Rate:                        0.128719
# Replacements:                               2250
# Total Samples:                             17480
# Nested Sampling ln(Z):                588.111041
# Acceptance Rate:                        0.128084
# Replacements:                               2300
# Total Samples:                             17957
# Nested Sampling ln(Z):                590.778960
# Acceptance Rate:                        0.127406
# Replacements:                               2350
# Total Samples:                             18445
# Nested Sampling ln(Z):                592.968379
# Acceptance Rate:                        0.126569
# Replacements:                               2400
# Total Samples:                             18962
# Nested Sampling ln(Z):                595.357836
# Acceptance Rate:                        0.125403
# Replacements:                               2450
# Total Samples:                             19537
# Nested Sampling ln(Z):                597.788067
# Acceptance Rate:                        0.124434
# Replacements:                               2500
# Total Samples:                             20091
# Nested Sampling ln(Z):                600.360054
# Acceptance Rate:                        0.123804
# Replacements:                               2550
# Total Samples:                             20597
# Nested Sampling ln(Z):                603.047084
# Acceptance Rate:                        0.122405
# Replacements:                               2600
# Total Samples:                             21241
# Nested Sampling ln(Z):                604.910986
# Acceptance Rate:                        0.121393
# Replacements:                               2650
# Total Samples:                             21830
# Nested Sampling ln(Z):                606.996734
# Acceptance Rate:                        0.119814
# Replacements:                               2700
# Total Samples:                             22535
# Nested Sampling ln(Z):                609.299769
# Acceptance Rate:                        0.118667
# Replacements:                               2750
# Total Samples:                             23174
# Nested Sampling ln(Z):                611.537446
# Acceptance Rate:                        0.118428
# Replacements:                               2800
# Total Samples:                             23643
# Nested Sampling ln(Z):                613.721115
# Acceptance Rate:                        0.115896
# Replacements:                               2850
# Total Samples:                             24591
# Nested Sampling ln(Z):                615.801464
# Acceptance Rate:                        0.114947
# Replacements:                               2900
# Total Samples:                             25229
# Nested Sampling ln(Z):                617.592959
# Acceptance Rate:                        0.113096
# Replacements:                               2950
# Total Samples:                             26084
# Nested Sampling ln(Z):                619.321807
# Acceptance Rate:                        0.112158
# Replacements:                               3000
# Total Samples:                             26748
# Nested Sampling ln(Z):                621.096719
# Acceptance Rate:                        0.110112
# Replacements:                               3050
# Total Samples:                             27699
# Nested Sampling ln(Z):                622.957785
# Acceptance Rate:                        0.109541
# Replacements:                               3100
# Total Samples:                             28300
# Nested Sampling ln(Z):                624.631735
# Acceptance Rate:                        0.108426
# Replacements:                               3150
# Total Samples:                             29052
# Nested Sampling ln(Z):                626.150483
# Acceptance Rate:                        0.107846
# Replacements:                               3200
# Total Samples:                             29672
# Nested Sampling ln(Z):                627.658309
# Acceptance Rate:                        0.106279
# Replacements:                               3250
# Total Samples:                             30580
# Nested Sampling ln(Z):                629.184777
# Acceptance Rate:                        0.105327
# Replacements:                               3300
# Total Samples:                             31331
# Nested Sampling ln(Z):                630.438899
# Acceptance Rate:                        0.104293
# Replacements:                               3350
# Total Samples:                             32121
# Nested Sampling ln(Z):                631.684659
# Acceptance Rate:                        0.103839
# Replacements:                               3400
# Total Samples:                             32743
# Nested Sampling ln(Z):                632.719282
# Acceptance Rate:                        0.103306
# Replacements:                               3450
# Total Samples:                             33396
# Nested Sampling ln(Z):                633.702557
# Acceptance Rate:                        0.102468
# Replacements:                               3500
# Total Samples:                             34157
# Nested Sampling ln(Z):                634.540886
# Acceptance Rate:                        0.101661
# Replacements:                               3550
# Total Samples:                             34920
# Nested Sampling ln(Z):                635.394646
# Acceptance Rate:                        0.100668
# Replacements:                               3600
# Total Samples:                             35761
# Nested Sampling ln(Z):                636.241566
# Acceptance Rate:                        0.100371
# Replacements:                               3650
# Total Samples:                             36365
# Nested Sampling ln(Z):                637.077783
# Acceptance Rate:                        0.099892
# Replacements:                               3700
# Total Samples:                             37040
# Nested Sampling ln(Z):                637.874078
# Acceptance Rate:                        0.099617
# Replacements:                               3750
# Total Samples:                             37644
# Nested Sampling ln(Z):                638.698407
# Acceptance Rate:                        0.098730
# Replacements:                               3800
# Total Samples:                             38489
# Nested Sampling ln(Z):                639.523450
# Acceptance Rate:                        0.098292
# Replacements:                               3850
# Total Samples:                             39169
# Nested Sampling ln(Z):                640.308449
# Acceptance Rate:                        0.097466
# Replacements:                               3900
# Total Samples:                             40014
# Nested Sampling ln(Z):                640.978675
# Acceptance Rate:                        0.097009
# Replacements:                               3950
# Total Samples:                             40718
# Nested Sampling ln(Z):                641.602654
# Acceptance Rate:                        0.095854
# Replacements:                               4000
# Total Samples:                             41730
# Nested Sampling ln(Z):                642.277779
# Acceptance Rate:                        0.094799
# Replacements:                               4050
# Total Samples:                             42722
# Nested Sampling ln(Z):                642.934012
# Acceptance Rate:                        0.093405
# Replacements:                               4100
# Total Samples:                             43895
# Nested Sampling ln(Z):                643.569747
# Acceptance Rate:                        0.092479
# Replacements:                               4150
# Total Samples:                             44875
# Nested Sampling ln(Z):                644.168754
# Acceptance Rate:                        0.091410
# Replacements:                               4200
# Total Samples:                             45947
# Nested Sampling ln(Z):                644.777520
# Acceptance Rate:                        0.090184
# Replacements:                               4250
# Total Samples:                             47126
# Nested Sampling ln(Z):                645.416828
# Acceptance Rate:                        0.089557
# Replacements:                               4300
# Total Samples:                             48014
# Nested Sampling ln(Z):                645.990133
# Acceptance Rate:                        0.088701
# Replacements:                               4350
# Total Samples:                             49041
# Nested Sampling ln(Z):                646.518204
# Acceptance Rate:                        0.088069
# Replacements:                               4400
# Total Samples:                             49961
# Nested Sampling ln(Z):                647.001736
# Acceptance Rate:                        0.087619
# Replacements:                               4450
# Total Samples:                             50788
# Nested Sampling ln(Z):                647.462116
# Acceptance Rate:                        0.086424
# Replacements:                               4500
# Total Samples:                             52069
# Nested Sampling ln(Z):                647.902501
# Acceptance Rate:                        0.085565
# Replacements:                               4550
# Total Samples:                             53176
# Nested Sampling ln(Z):                648.322473
# Acceptance Rate:                        0.084694
# Replacements:                               4600
# Total Samples:                             54313
# Nested Sampling ln(Z):                648.723011
# Acceptance Rate:                        0.083793
# Replacements:                               4650
# Total Samples:                             55494
# Nested Sampling ln(Z):                649.085842
# Acceptance Rate:                        0.082969
# Replacements:                               4700
# Total Samples:                             56648
# Nested Sampling ln(Z):                649.407371
# Acceptance Rate:                        0.082450
# Replacements:                               4750
# Total Samples:                             57611
# Nested Sampling ln(Z):                649.726449
# Acceptance Rate:                        0.082182
# Replacements:                               4800
# Total Samples:                             58407
# Nested Sampling ln(Z):                650.046680
# Acceptance Rate:                        0.081327
# Replacements:                               4850
# Total Samples:                             59636
# Nested Sampling ln(Z):                650.363117
# Acceptance Rate:                        0.080546
# Replacements:                               4900
# Total Samples:                             60835
# Nested Sampling ln(Z):                650.662594
# Acceptance Rate:                        0.080094
# Replacements:                               4950
# Total Samples:                             61802
# Nested Sampling ln(Z):                650.959363
# Acceptance Rate:                        0.079805
# Replacements:                               5000
# Total Samples:                             62653
# Nested Sampling ln(Z):                651.241785
# Acceptance Rate:                        0.079212
# Replacements:                               5050
# Total Samples:                             63753
# Nested Sampling ln(Z):                651.514487
# Acceptance Rate:                        0.078585
# Replacements:                               5100
# Total Samples:                             64898
# Nested Sampling ln(Z):                651.773417
# Acceptance Rate:                        0.078127
# Replacements:                               5150
# Total Samples:                             65918
# Nested Sampling ln(Z):                652.017601
# Acceptance Rate:                        0.077931
# Replacements:                               5200
# Total Samples:                             66726
# Nested Sampling ln(Z):                652.252414
# Acceptance Rate:                        0.077410
# Replacements:                               5250
# Total Samples:                             67821
# Nested Sampling ln(Z):                652.476994
# Acceptance Rate:                        0.077097
# Replacements:                               5300
# Total Samples:                             68745
# Nested Sampling ln(Z):                652.686976
# Acceptance Rate:                        0.076645
# Replacements:                               5350
# Total Samples:                             69802
# Nested Sampling ln(Z):                652.888300
# Acceptance Rate:                        0.075953
# Replacements:                               5400
# Total Samples:                             71097
# Nested Sampling ln(Z):                653.078544
# Acceptance Rate:                        0.075643
# Replacements:                               5450
# Total Samples:                             72049
# Nested Sampling ln(Z):                653.258555
# Acceptance Rate:                        0.075082
# Replacements:                               5500
# Total Samples:                             73253
# Nested Sampling ln(Z):                653.431029
# Acceptance Rate:                        0.074813
# Replacements:                               5550
# Total Samples:                             74185
# Nested Sampling ln(Z):                653.587247
# Acceptance Rate:                        0.074548
# Replacements:                               5600
# Total Samples:                             75119
# Nested Sampling ln(Z):                653.738454
# Acceptance Rate:                        0.074220
# Replacements:                               5650
# Total Samples:                             76125
# Nested Sampling ln(Z):                653.881285
# Acceptance Rate:                        0.073904
# Replacements:                               5700
# Total Samples:                             77127
# Nested Sampling ln(Z):                654.012877
# Acceptance Rate:                        0.073508
# Replacements:                               5750
# Total Samples:                             78223
# Nested Sampling ln(Z):                654.135200
# Acceptance Rate:                        0.073170
# Replacements:                               5800
# Total Samples:                             79268
# Nested Sampling ln(Z):                654.250278
# Acceptance Rate:                        0.073062
# Replacements:                               5850
# Total Samples:                             80069
# Nested Sampling ln(Z):                654.357001
# Acceptance Rate:                        0.072486
# Replacements:                               5900
# Total Samples:                             81395
# Nested Sampling ln(Z):                654.456812
# Acceptance Rate:                        0.072006
# Replacements:                               5950
# Total Samples:                             82632
# Nested Sampling ln(Z):                654.549088
# Acceptance Rate:                        0.071513
# Replacements:                               6000
# Total Samples:                             83901
# Nested Sampling ln(Z):                654.632110
# Acceptance Rate:                        0.071310
# Replacements:                               6050
# Total Samples:                             84841
# Nested Sampling ln(Z):                654.709841
# Acceptance Rate:                        0.071061
# Replacements:                               6100
# Total Samples:                             85842
# Nested Sampling ln(Z):                654.782448
# Acceptance Rate:                        0.070901
# Replacements:                               6150
# Total Samples:                             86741
# Nested Sampling ln(Z):                654.849195
# Acceptance Rate:                        0.070741
# Replacements:                               6200
# Total Samples:                             87644
# Nested Sampling ln(Z):                654.910921
# Acceptance Rate:                        0.070482
# Replacements:                               6250
# Total Samples:                             88675
# Nested Sampling ln(Z):                654.968580
# Acceptance Rate:                        0.070211
# Replacements:                               6300
# Total Samples:                             89730
# Nested Sampling ln(Z):                655.022495
# Acceptance Rate:                        0.070081
# Replacements:                               6350
# Total Samples:                             90610
# Nested Sampling ln(Z):                655.074265
# Acceptance Rate:                        0.069990
# Replacements:                               6400
# Total Samples:                             91442
# Nested Sampling ln(Z):                655.122444
# Acceptance Rate:                        0.069732
# Replacements:                               6450
# Total Samples:                             92497
# Nested Sampling ln(Z):                655.167676
# Acceptance Rate:                        0.069532
# Replacements:                               6500
# Total Samples:                             93482
# Nested Sampling ln(Z):                655.209448
# Acceptance Rate:                        0.069392
# Replacements:                               6550
# Total Samples:                             94391
# Nested Sampling ln(Z):                655.248236
# Acceptance Rate:                        0.069148
# Replacements:                               6600
# Total Samples:                             95447
# Nested Sampling ln(Z):                655.284126
# Acceptance Rate:                        0.068942
# Replacements:                               6650
# Total Samples:                             96458
# Nested Sampling ln(Z):                655.316538
# Acceptance Rate:                        0.068643
# Replacements:                               6700
# Total Samples:                             97607
# Nested Sampling ln(Z):                655.346212
# Acceptance Rate:                        0.068542
# Replacements:                               6750
# Total Samples:                             98480
# Nested Sampling ln(Z):                655.373108
# Acceptance Rate:                        0.068110
# Replacements:                               6800
# Total Samples:                             99839
# Nested Sampling ln(Z):                655.397893
# Acceptance Rate:                        0.067663
# Replacements:                               6850
# Total Samples:                            101237
# Nested Sampling ln(Z):                655.420635
# Acceptance Rate:                        0.067597
# Replacements:                               6856
# Total Samples:                            101424
# Nested Sampling ln(Z):                655.423228
#  ln(ev)=   655.64075927650879      +/-  0.17888465106642598
#  Total Likelihood Evaluations:       101424
#
# Completed in 207.7 seconds.
#
#  Sampling finished. Exiting MultiNest
# Parameter                          Posterior percentiles
#                                 16th       50th       84th
# ----------------------------------------------------------
# continuity:dsfr1              -0.314      0.017      0.344
# continuity:dsfr2              -0.114      0.161      0.562
# continuity:dsfr3               0.074      0.313      0.746
# continuity:dsfr4               0.096      0.375      0.866
# continuity:dsfr5               0.805      1.231      2.141
# continuity:massformed          7.963      8.099      8.318
# continuity:metallicity         0.183      0.293      0.430
# dust:Av                        0.152      0.209      0.274
# nebular:logU                  -2.513     -2.365     -2.196

# %%
out_params = {}
for p in fit.posterior.samples.keys():
    out_params[p] = fit.posterior.samples[p]
    p16,p50,p84 = np.percentile(out_params[p],[16,50,84])
    pStr = p+' '*(30-len(p))
    print(pStr,'\t','%.4f' % p16,'\t','%.4f' % p50,'\t','%.4f' % p84)
# Out:
# continuity:dsfr1               	 -0.2849 	 0.0374 	 0.3243
# continuity:dsfr2               	 -0.0880 	 0.1608 	 0.5618
# continuity:dsfr3               	 0.0694 	 0.3064 	 0.7295
# continuity:dsfr4               	 0.0770 	 0.3534 	 0.8627
# continuity:dsfr5               	 0.8393 	 1.2366 	 2.1521
# continuity:massformed          	 7.9703 	 8.0998 	 8.3199
# continuity:metallicity         	 0.1791 	 0.3003 	 0.4338
# dust:Av                        	 0.1556 	 0.2134 	 0.2763
# nebular:logU                   	 -2.5034 	 -2.3618 	 -2.1979
# stellar_mass                   	 7.9374 	 8.0423 	 8.2213
# formed_mass                    	 7.9703 	 8.0998 	 8.3199
# sfr                            	 0.8859 	 1.0336 	 1.3039
# ssfr                           	 -8.1344 	 -8.0147 	 -7.9744
# nsfr                           	 0.7272 	 0.8901 	 0.9592
# mass_weighted_age              	 0.0102 	 0.0547 	 0.1284
# tform                          	 0.7886 	 0.8623 	 0.9068
# tquench                        	 99.0000 	 99.0000 	 99.0000
# mass_weighted_zmet             	 0.1792 	 0.3002 	 0.4337
# sfh                            	 0.0000 	 0.0640 	 7.3868

# %%
fig,ax = plt.subplots(figsize=(7,6))
hist = ax.hist(out_params['formed_mass'],range=(5,10),bins=100)

# %%
fit.posterior.get_advanced_quantities()

fig = fit.plot_spectrum_posterior(save=False, show=True)
fig = fit.plot_sfh_posterior(save=False, show=True)
fig = fit.plot_corner(save=False, show=True)

plt.show()

# %%
#plot output SED in microJy vs. micron units

def makeABMagmuJy(x): #converts from microJy to AB mag
    if hasattr(x, "__len__"):
        ABx=np.zeros(len(x))
        for i in range(len(x)):
            if(x[i]<=0):
                ABx[i]=100.
            else:
                ABx[i]=-2.5*np.log10(x[i])+23.9
        return ABx
    else:
        if(x<=0):
            return 100.
        else:
            return -2.5*np.log10(x)+23.9

c_light = 2.99792e+18 # Ang/s
microJy = 1e-29 #erg/s/cm^2/Hz per microJy

wl = fit.posterior.model_galaxy.wavelengths
myz = 6.0

SEDs = fit.posterior.samples["spectrum_full"] #in F_lambda units (erg/s/cm^2/A) in some kind of rest-frame
mySEDs = ((wl**2 * SEDs).T/c_light/microJy*(1.+myz)**2).T #convert to microJy observed-frame
medzwl = wl*(1.+myz)
medSED = np.percentile(mySEDs,50,axis=0)
lowSED = np.percentile(mySEDs,16,axis=0)
uppSED = np.percentile(mySEDs,84,axis=0)

fig,ax = plt.subplots(figsize=(7,6))
ax.plot(medzwl/1e4, 
        makeABMagmuJy(medSED),
        color = "black",
        lw=1.,
        alpha=0.7)
ax.fill_between(medzwl/1e4,makeABMagmuJy(uppSED),makeABMagmuJy(lowSED),color='gray',alpha=0.3)

ax.set_xscale('log')
ax.set_xlim(0.3,7)
ax.set_ylim(32,24)

ax.set_ylabel('AB Magnitude')
ax.set_xlabel('Observed Wavelength [microns]')
# Out:
# Text(0.5, 0, 'Observed Wavelength [microns]')
